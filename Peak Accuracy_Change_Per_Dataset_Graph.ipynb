# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = {
    'Dataset Name': ['Sports15', 'Vehicle20', 'Flowers10', 'Food10', 'Fruits10', 'Food34', 'Weather11', 
                     'Animal80', 'Card4', 'Veg7', 'Animal4', 'CatDog2', 'SeaAnimals23', 'Pests12', 'Animals15', 
                     'Dog10', 'Apparel24', 'Reptiles10', 'Sports22', 'Animals64'],
    'Peak Accuracy Change': [5.31, 1.33, 8.31, 1.82, 0.75, 3.43, 5.30, 1.72, 0.00, 0.00, 1.37, 3.41, 4.28, 3.23, 0.00, 2.06, 
                             0.11, 0.00, 0.00, 0.43]
}

# %%
df = pd.DataFrame(data)

plt.figure(figsize=(10, 6))
plt.barh(df['Dataset Name'], df['Peak Accuracy Change'], color='skyblue')
plt.xlabel('Peak Accuracy Change (%)', fontsize=18)
plt.title('Peak Accuracy Change per Dataset', fontsize=22)

plt.yticks(fontsize=13)

plt.tight_layout()
plt.show()
